# %%
import pandas as pd

df_seq = pd.read_csv('../data/seq/fall_67.csv')
df_seq
# Out:
#           ax         ay        az  fall_state    g_force
# 0  -6.322063   6.635534  4.039229           0  10.015696
# 1  -6.444101   6.953791  3.603719           0  10.142408
# 2   3.223247   9.004513 -3.192139           1  10.082675
# 3   1.646321   6.422565 -4.228269           1   7.863713
# 4   3.601327   9.387379 -6.477602           1  11.960425
# ..       ...        ...       ...         ...        ...
# 78 -0.851875  10.930804  0.744194           0  10.989176
# 79 -0.947592   8.748472  1.359172           0   8.903990
# 80 -0.265613   8.882475  1.179704           0   8.964408
# 81 -0.516868  10.392400  0.562333           0  10.420429
# 82  1.115095   6.561354  1.244312           0   6.770755
#
# [83 rows x 5 columns]

# %%
# show all the files in this directory ../data/seq/ 
import os
for file in os.listdir('../data/seq/'):
    print(file)
    df = pd.read_csv('../data/seq/' + file)
    print(df)
    print()
# Out:
# non_fall_54.csv
#           ax         ay        az  fall_state    g_force
# 0  -3.304606   6.738429 -5.436687           0   9.267384
# 1  -3.663542   8.186138 -5.687943           0  10.620127
# 2  -4.613527   6.240705 -4.376629           0   8.909877
# 3  -3.649185   7.054293 -3.400322           0   8.639548
# 4  -3.474503   7.781737 -1.524282           0   8.657427
# 5  -3.187354   7.664485 -0.346972           0   8.308064
# 6  -2.297192   7.846345  0.284756           0   8.180667
# 7  -3.558254   9.234232  0.313471           0   9.901034
# 8   0.808803  12.163152  0.878197           0  12.221606
# 9   6.381886   9.270126 -2.885847           0  11.618598
# 10  2.519732  11.019341  1.160560           0  11.363179
# 11  3.007885  12.278011  0.244077           0  12.643437
# 12  3.041386   9.624276  1.143810           0  10.158003
# 13  2.871490  12.505338  0.598227           0  12.844719
# 14  2.632199   9.105016 -1.244312           0   9.559189
# ...
